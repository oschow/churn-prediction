# %%
# %matplotlib inline

# %%
run knn_case_study.py
# Out:
# Train Accuracy: 0.722279822591
# Train Recall: 0.854670799981
# Train Precision: 0.739649235205
# Test Accuracy: 0.722617927698
# Test Recall: 0.852682403433
# Test Precision: 0.742571481966

# %%
run logistic_regression.py
# Out:
# Optimization terminated successfully.
#          Current function value: 0.561650
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                  churn   No. Observations:                49604
# Model:                          Logit   Df Residuals:                    49597
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 23 Sep 2016   Pseudo R-squ.:                  0.1519
# Time:                        17:45:48   Log-Likelihood:                -27860.
# converged:                       True   LL-Null:                       -32851.
#                                         LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          2.4618      0.034     72.058      0.000         2.395     2.529
# ...
